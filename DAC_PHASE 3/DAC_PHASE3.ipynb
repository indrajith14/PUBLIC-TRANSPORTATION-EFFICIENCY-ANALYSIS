# %% [markdown]
# # DAC_PHASE 3
# # Date :26/10/2023
# # Project Title :Public Transportation Efficiency Analysis

# %% [markdown]
# ## Importing The Dependencies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("C://Users//Indarjith K//Desktop//Indrajithdataset.csv")
# Out:
# C:\Users\Indarjith K\AppData\Local\Temp\ipykernel_10320\2758608790.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("C://Users//Indarjith K//Desktop//Indrajithdataset.csv")

# %%
data
# Out:
#          TripID RouteID  StopID                    StopName     WeekBeginning  \
# 0         23631     100   14156                181 Cross Rd  30-06-2013 00:00
# 1         23631     100   14144                177 Cross Rd  30-06-2013 00:00
# 2         23632     100   14132                175 Cross Rd  30-06-2013 00:00
# 3         23633     100   12266  Zone A Arndale Interchange  30-06-2013 00:00
# 4         23633     100   14147                178 Cross Rd  30-06-2013 00:00
# ...         ...     ...     ...                         ...               ...
# 1048570   45682     171   13929              8 Fullarton Rd  29-09-2013 00:00
# 1048571   45682     171   13758            3 Glen Osmond Rd  29-09-2013 00:00
# 1048572   45682     171   13967              9 Fullarton Rd  29-09-2013 00:00
# 1048573   45682     171   13808              5 Fullarton Rd  29-09-2013 00:00
# 1048574   45682     171   13845              6 Fullarton Rd  29-09-2013 00:00
#
#          NumberOfBoardings
# 0                        1
# 1                        1
# 2                        1
# 3                        2
# 4                        1
# ...                    ...
# 1048570                  2
# 1048571                  3
# 1048572                  1
# 1048573                  1
# 1048574                  3
#
# [1048575 rows x 6 columns]

# %% [markdown]
# # EXPLORING THE DATASET

# %% [markdown]
# ## 1. Displaying The Top 5 Rows

# %%
data.head()
# Out:
#    TripID RouteID  StopID                    StopName     WeekBeginning  \
# 0   23631     100   14156                181 Cross Rd  30-06-2013 00:00
# 1   23631     100   14144                177 Cross Rd  30-06-2013 00:00
# 2   23632     100   14132                175 Cross Rd  30-06-2013 00:00
# 3   23633     100   12266  Zone A Arndale Interchange  30-06-2013 00:00
# 4   23633     100   14147                178 Cross Rd  30-06-2013 00:00
#
#    NumberOfBoardings
# 0                  1
# 1                  1
# 2                  1
# 3                  2
# 4                  1

# %% [markdown]
# ## 2. Displaying The Bottom 5 Rows

# %%
data.tail()
# Out:
#          TripID RouteID  StopID          StopName     WeekBeginning  \
# 1048570   45682     171   13929    8 Fullarton Rd  29-09-2013 00:00
# 1048571   45682     171   13758  3 Glen Osmond Rd  29-09-2013 00:00
# 1048572   45682     171   13967    9 Fullarton Rd  29-09-2013 00:00
# 1048573   45682     171   13808    5 Fullarton Rd  29-09-2013 00:00
# 1048574   45682     171   13845    6 Fullarton Rd  29-09-2013 00:00
#
#          NumberOfBoardings
# 1048570                  2
# 1048571                  3
# 1048572                  1
# 1048573                  1
# 1048574                  3

# %% [markdown]
# ## 3. Find The Shape Of The Dataset

# %%
data.shape
# Out:
# (1048575, 6)

# %% [markdown]
# ## 4. Displaying The Information

# %%
data.info
# Out:
# <bound method DataFrame.info of          TripID RouteID  StopID                    StopName     WeekBeginning  \
# 0         23631     100   14156                181 Cross Rd  30-06-2013 00:00
# 1         23631     100   14144                177 Cross Rd  30-06-2013 00:00
# 2         23632     100   14132                175 Cross Rd  30-06-2013 00:00
# 3         23633     100   12266  Zone A Arndale Interchange  30-06-2013 00:00
# 4         23633     100   14147                178 Cross Rd  30-06-2013 00:00
# ...         ...     ...     ...                         ...               ...
# 1048570   45682     171   13929              8 Fullarton Rd  29-09-2013 00:00
# 1048571   45682     171   13758            3 Glen Osmond Rd  29-09-2013 00:00
# 1048572   45682     171   13967              9 Fullarton Rd  29-09-2013 00:00
# 1048573   45682     171   13808              5 Fullarton Rd  29-09-2013 00:00
# 1048574   45682     171   13845              6 Fullarton Rd  29-09-2013 00:00
#
#          NumberOfBoardings
# 0                        1
# 1                        1
# 2                        1
# 3                        2
# 4                        1
# ...                    ...
# 1048570                  2
# 1048571                  3
# 1048572                  1
# 1048573                  1
# 1048574                  3
#
# [1048575 rows x 6 columns]>

# %% [markdown]
# ## 5. Cheking For Null Values

# %%
data.isnull().sum()
# Out:
# TripID               0
# RouteID              0
# StopID               0
# StopName             0
# WeekBeginning        0
# NumberOfBoardings    0
# dtype: int64

# %% [markdown]
# ## 6. Check For Duplicate And Drop Them

# %%
dup = data.duplicated().any()

# %%
print(dup)
# Out:
# False

# %% [markdown]
# ## 7. Get The Entire Statistics Of The Data

# %%
data.describe()
# Out:
#              TripID        StopID  NumberOfBoardings
# count  1.048575e+06  1.048575e+06       1.048575e+06
# mean   2.860299e+04  1.330114e+04       4.132290e+00
# std    1.674656e+04  1.119243e+03       6.291338e+00
# min    3.017000e+03  1.081700e+04       1.000000e+00
# 25%    1.162200e+04  1.269800e+04       1.000000e+00
# 50%    3.423400e+04  1.333500e+04       2.000000e+00
# 75%    4.512600e+04  1.371600e+04       4.000000e+00
# max    6.258500e+04  1.849300e+04       1.930000e+02

# %% [markdown]
# # VISUALISING THE DATA

# %%
sns.histplot(data, x='TripID', bins=10, color='y')
# Out:
# <Axes: xlabel='TripID', ylabel='Count'>

# %%
sns.histplot(data, x='StopID', bins=10, color='y')
# Out:
# <Axes: xlabel='StopID', ylabel='Count'>

# %%
M=(data.groupby('TripID')['NumberOfBoardings']).sum()

# %%
M
# Out:
# TripID
# 3017      2
# 3020      2
# 3021      1
# 3022      3
# 3023      1
#          ..
# 62581     4
# 62582    11
# 62583     4
# 62584    11
# 62585    11
# Name: NumberOfBoardings, Length: 3299, dtype: int64

# %%
M.plot.bar()
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.pairplot(data)
# Out:
# C:\Users\Indarjith K\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
data.hist(figsize=(10,8))
# Out:
# array([[<Axes: title={'center': 'TripID'}>,
#         <Axes: title={'center': 'StopID'}>],
#        [<Axes: title={'center': 'NumberOfBoardings'}>, <Axes: >]],
#       dtype=object)

# %%
C=data.groupby('StopName')['TripID'].sum().sort_values(ascending = False)
C
# Out:
# StopName
# I1 North Tce          357980471
# 23  Findon Rd         280075267
# 21 Port Rd            278666250
# R1 North Tce          276122712
# B1 East Tce           243863395
#                         ...
# X2 King William St        22448
# V2 King William St        22444
# I2 North Tce              12813
# L1 Unley Rd               11221
# 11 East Av                 5613
# Name: TripID, Length: 583, dtype: int64

# %%
C.plot.bar(figsize=(20,5))
plt.show()

# %% [markdown]
# ##  How many passengers weekBeginning

# %%
WeekBeginning = data.groupby(['RouteID','WeekBeginning'])[['NumberOfBoardings']].sum()
WeekBeginning
# Out:
#                           NumberOfBoardings
# RouteID WeekBeginning
# 117     01-06-2014 00:00               7837
#         01-09-2013 00:00               4435
#         01-12-2013 00:00               7539
#         02-02-2014 00:00               8272
#         02-03-2014 00:00               8059
# ...                                     ...
# 168     07-07-2013 00:00               5577
#         14-07-2013 00:00               5411
#         21-07-2013 00:00               6340
#         28-07-2013 00:00               7046
#         30-06-2013 00:00               6208
#
# [1519 rows x 1 columns]

# %%
WeekBeginning.unstack(level=0).plot(kind='bar',subplots=True,figsize=(20,10))
plt.show()

# %%
data.corr
# Out:
# <bound method DataFrame.corr of          TripID RouteID  StopID                    StopName     WeekBeginning  \
# 0         23631     100   14156                181 Cross Rd  30-06-2013 00:00
# 1         23631     100   14144                177 Cross Rd  30-06-2013 00:00
# 2         23632     100   14132                175 Cross Rd  30-06-2013 00:00
# 3         23633     100   12266  Zone A Arndale Interchange  30-06-2013 00:00
# 4         23633     100   14147                178 Cross Rd  30-06-2013 00:00
# ...         ...     ...     ...                         ...               ...
# 1048570   45682     171   13929              8 Fullarton Rd  29-09-2013 00:00
# 1048571   45682     171   13758            3 Glen Osmond Rd  29-09-2013 00:00
# 1048572   45682     171   13967              9 Fullarton Rd  29-09-2013 00:00
# 1048573   45682     171   13808              5 Fullarton Rd  29-09-2013 00:00
# 1048574   45682     171   13845              6 Fullarton Rd  29-09-2013 00:00
#
#          NumberOfBoardings
# 0                        1
# 1                        1
# 2                        1
# 3                        2
# 4                        1
# ...                    ...
# 1048570                  2
# 1048571                  3
# 1048572                  1
# 1048573                  1
# 1048574                  3
#
# [1048575 rows x 6 columns]>

# %%
sns.lineplot(x="StopID", y="TripID", data=data)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
